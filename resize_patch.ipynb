# %%
import nibabel as nib
import numpy as np
import os
from patchify import patchify, unpatchify
from scipy import ndimage
import re
import cv2


class Resize3D:
    def __init__(self, target_size, model='constant', order=1):
        self.model = model
        self.order = order

        if isinstance(target_size, list) or isinstance(target_size, tuple):
            if len(target_size) != 3:
                raise ValueError(
                    '`target_size` should include 3 elements, but it is {}'.
                    format(target_size))

        else:
            raise TypeError(
                "Type of `target_size` is invalid. It should be list or tuple, but it is {}"
                .format(type(target_size)))

        self.target_size = target_size

    def __call__(self, im, label=None):
        if not isinstance(im, np.ndarray):
            raise TypeError("Resize: image type is not numpy.")
        if len(im.shape) != 3:
            raise ValueError('Resize: image is not 3-dimensional.')
        if im.ndim == 3:
            desired_depth = self.target_size[2]  # 深度
            desired_width = self.target_size[1]
            desired_height = self.target_size[0]

            current_depth = im.shape[2]  # 深度
            current_width = im.shape[1]
            current_height = im.shape[0]

            depth = current_depth / desired_depth
            width = current_width / desired_width
            height = current_height / desired_height
            depth_factor = 1 / depth
            width_factor = 1 / width
            height_factor = 1 / height

            im = ndimage.zoom(im, (height_factor, width_factor, depth_factor), order=self.order, mode=self.model)
            if label is not None:
                label = ndimage.zoom(label, (height_factor, width_factor, depth_factor), order=0, mode='nearest',
                                     cval=0.0)

        else:
            raise ValueError('Resize: target_size is not 3-dimensional.')

        if label is None:
            return im
        else:
            return (im, label)


def crop(image, patch_size):
    cropped_image_list = []
    patches = patchify(image, patch_size, step=patch_size)
    for d in range(patches.shape[0]):
        for h in range(patches.shape[1]):
            for w in range(patches.shape[2]):
                # 从 patches 中获取一个小块
                cropped_image_list.append(patches[d, h, w])

    return cropped_image_list


def equalization(image):
    a, b, c = image.shape
    flattened_image = image.flatten()
    equalized_image = cv2.equalizeHist(flattened_image)

    return equalized_image.reshape(a, b, c)


def nii_save(imlist, filedir, index, affine):
    os.makedirs(filedir, exist_ok=True)  # 디렉토리 생성
    for i in range(len(imlist)):
        data = imlist[i].squeeze()
        nifti_image = nib.Nifti1Image(data, affine)
        filename = f'CT{index}_{i+1:04d}.nii.gz'  # 파일 이름 형식 변경
        filepath = os.path.join(filedir, filename)
        nib.save(nifti_image, filepath)
        print(f'{filename} saved successfully!')



pattern = re.compile(r".*\.nii\.gz$")
image_dir = r'/home/chae/segmentation/dataset/ct_train'
label_dir = r'/home/chae/segmentation/dataset/ct_label'
image_list = [file for file in sorted(os.listdir(image_dir)) if pattern.match(file)]
label_list = [file for file in sorted(os.listdir(label_dir)) if pattern.match(file)]
for idx in range(len(image_list)):
    image_path = os.path.join(image_dir, image_list[idx])
    label_path = os.path.join(label_dir, label_list[idx])

    img = nib.load(image_path)
    img_data = img.get_fdata()
    affine1 = img.affine if hasattr(img, 'affine') else np.eye(4)
    img_data = (img_data / np.max(img_data) * 255).astype(np.uint8)
    img_data = equalization(img_data)

    label = nib.load(label_path)
    label_data = label.get_fdata()
    affine2 = img.affine if hasattr(label, 'affine') else np.eye(4)

    target_size = (512, 512, 384)
    resize3d = Resize3D(target_size=target_size)
    img_data, label_data = resize3d(img_data, label=label_data)

    output_size = (64, 64, 64)
    img_list = crop(img_data, output_size)
    lab_list = crop(label_data, output_size)

    nii_save(img_list, r'/home/chae/segmentation/dataset/ct_train_patch', f'train_{idx+1}', affine1)
    nii_save(lab_list, r'/home/chae/segmentation/dataset/ct_label_patch', f'label_{idx+1}', affine2)
# Out:
# CTtrain_1_0001.nii.gz saved successfully!
# CTtrain_1_0002.nii.gz saved successfully!
# CTtrain_1_0003.nii.gz saved successfully!
# CTtrain_1_0004.nii.gz saved successfully!
# CTtrain_1_0005.nii.gz saved successfully!
# CTtrain_1_0006.nii.gz saved successfully!
# CTtrain_1_0007.nii.gz saved successfully!
# CTtrain_1_0008.nii.gz saved successfully!
# CTtrain_1_0009.nii.gz saved successfully!
# CTtrain_1_0010.nii.gz saved successfully!
# CTtrain_1_0011.nii.gz saved successfully!
# CTtrain_1_0012.nii.gz saved successfully!
# CTtrain_1_0013.nii.gz saved successfully!
# CTtrain_1_0014.nii.gz saved successfully!
# CTtrain_1_0015.nii.gz saved successfully!
# CTtrain_1_0016.nii.gz saved successfully!
# CTtrain_1_0017.nii.gz saved successfully!
# CTtrain_1_0018.nii.gz saved successfully!
# CTtrain_1_0019.nii.gz saved successfully!
# CTtrain_1_0020.nii.gz saved successfully!
# CTtrain_1_0021.nii.gz saved successfully!
# CTtrain_1_0022.nii.gz saved successfully!
# CTtrain_1_0023.nii.gz saved successfully!
# CTtrain_1_0024.nii.gz saved successfully!
# CTtrain_1_0025.nii.gz saved successfully!
# CTtrain_1_0026.nii.gz saved successfully!
# CTtrain_1_0027.nii.gz saved successfully!
# CTtrain_1_0028.nii.gz saved successfully!
# CTtrain_1_0029.nii.gz saved successfully!
# CTtrain_1_0030.nii.gz saved successfully!
# CTtrain_1_0031.nii.gz saved successfully!
# CTtrain_1_0032.nii.gz saved successfully!
# CTtrain_1_0033.nii.gz saved successfully!
# CTtrain_1_0034.nii.gz saved successfully!
# CTtrain_1_0035.nii.gz saved successfully!
# CTtrain_1_0036.nii.gz saved successfully!
# CTtrain_1_0037.nii.gz saved successfully!
# CTtrain_1_0038.nii.gz saved successfully!
# CTtrain_1_0039.nii.gz saved successfully!
# CTtrain_1_0040.nii.gz saved successfully!
# CTtrain_1_0041.nii.gz saved successfully!
# CTtrain_1_0042.nii.gz saved successfully!
# CTtrain_1_0043.nii.gz saved successfully!
# CTtrain_1_0044.nii.gz saved successfully!
# CTtrain_1_0045.nii.gz saved successfully!
# CTtrain_1_0046.nii.gz saved successfully!
# CTtrain_1_0047.nii.gz saved successfully!
# CTtrain_1_0048.nii.gz saved successfully!
# CTtrain_1_0049.nii.gz saved successfully!
# CTtrain_1_0050.nii.gz saved successfully!
# CTtrain_1_0051.nii.gz saved successfully!
# CTtrain_1_0052.nii.gz saved successfully!
# CTtrain_1_0053.nii.gz saved successfully!
# CTtrain_1_0054.nii.gz saved successfully!
# CTtrain_1_0055.nii.gz saved successfully!
# CTtrain_1_0056.nii.gz saved successfully!
# CTtrain_1_0057.nii.gz saved successfully!
# CTtrain_1_0058.nii.gz saved successfully!
# CTtrain_1_0059.nii.gz saved successfully!
# CTtrain_1_0060.nii.gz saved successfully!
# CTtrain_1_0061.nii.gz saved successfully!
# CTtrain_1_0062.nii.gz saved successfully!
# CTtrain_1_0063.nii.gz saved successfully!
# CTtrain_1_0064.nii.gz saved successfully!
# CTtrain_1_0065.nii.gz saved successfully!
# CTtrain_1_0066.nii.gz saved successfully!
# CTtrain_1_0067.nii.gz saved successfully!
# CTtrain_1_0068.nii.gz saved successfully!
# CTtrain_1_0069.nii.gz saved successfully!
# CTtrain_1_0070.nii.gz saved successfully!
# CTtrain_1_0071.nii.gz saved successfully!
# CTtrain_1_0072.nii.gz saved successfully!
# CTtrain_1_0073.nii.gz saved successfully!
# CTtrain_1_0074.nii.gz saved successfully!
# CTtrain_1_0075.nii.gz saved successfully!
# CTtrain_1_0076.nii.gz saved successfully!
# CTtrain_1_0077.nii.gz saved successfully!
# CTtrain_1_0078.nii.gz saved successfully!
# CTtrain_1_0079.nii.gz saved successfully!
# CTtrain_1_0080.nii.gz saved successfully!
# CTtrain_1_0081.nii.gz saved successfully!
# CTtrain_1_0082.nii.gz saved successfully!
# CTtrain_1_0083.nii.gz saved successfully!
# CTtrain_1_0084.nii.gz saved successfully!
# CTtrain_1_0085.nii.gz saved successfully!
# CTtrain_1_0086.nii.gz saved successfully!
# CTtrain_1_0087.nii.gz saved successfully!
# CTtrain_1_0088.nii.gz saved successfully!
# CTtrain_1_0089.nii.gz saved successfully!
# CTtrain_1_0090.nii.gz saved successfully!
# CTtrain_1_0091.nii.gz saved successfully!
# CTtrain_1_0092.nii.gz saved successfully!
# CTtrain_1_0093.nii.gz saved successfully!
# CTtrain_1_0094.nii.gz saved successfully!
# CTtrain_1_0095.nii.gz saved successfully!
# CTtrain_1_0096.nii.gz saved successfully!
# CTtrain_1_0097.nii.gz saved successfully!
# CTtrain_1_0098.nii.gz saved successfully!
# CTtrain_1_0099.nii.gz saved successfully!
# CTtrain_1_0100.nii.gz saved successfully!
# CTtrain_1_0101.nii.gz saved successfully!
# CTtrain_1_0102.nii.gz saved successfully!
# CTtrain_1_0103.nii.gz saved successfully!
# CTtrain_1_0104.nii.gz saved successfully!
# CTtrain_1_0105.nii.gz saved successfully!
# CTtrain_1_0106.nii.gz saved successfully!
# CTtrain_1_0107.nii.gz saved successfully!
# CTtrain_1_0108.nii.gz saved successfully!
# CTtrain_1_0109.nii.gz saved successfully!
# CTtrain_1_0110.nii.gz saved successfully!
# CTtrain_1_0111.nii.gz saved successfully!
# CTtrain_1_0112.nii.gz saved successfully!
# CTtrain_1_0113.nii.gz saved successfully!
# CTtrain_1_0114.nii.gz saved successfully!
# CTtrain_1_0115.nii.gz saved successfully!
# CTtrain_1_0116.nii.gz saved successfully!
# CTtrain_1_0117.nii.gz saved successfully!
# CTtrain_1_0118.nii.gz saved successfully!
# CTtrain_1_0119.nii.gz saved successfully!
# CTtrain_1_0120.nii.gz saved successfully!
# CTtrain_1_0121.nii.gz saved successfully!
# CTtrain_1_0122.nii.gz saved successfully!
# CTtrain_1_0123.nii.gz saved successfully!
# CTtrain_1_0124.nii.gz saved successfully!
# CTtrain_1_0125.nii.gz saved successfully!
# CTtrain_1_0126.nii.gz saved successfully!
# CTtrain_1_0127.nii.gz saved successfully!
# CTtrain_1_0128.nii.gz saved successfully!
# CTtrain_1_0129.nii.gz saved successfully!
# CTtrain_1_0130.nii.gz saved successfully!
# CTtrain_1_0131.nii.gz saved successfully!
# CTtrain_1_0132.nii.gz saved successfully!
# CTtrain_1_0133.nii.gz saved successfully!
# CTtrain_1_0134.nii.gz saved successfully!
# CTtrain_1_0135.nii.gz saved successfully!
# CTtrain_1_0136.nii.gz saved successfully!
# CTtrain_1_0137.nii.gz saved successfully!
# CTtrain_1_0138.nii.gz saved successfully!
# CTtrain_1_0139.nii.gz saved successfully!
# CTtrain_1_0140.nii.gz saved successfully!
# CTtrain_1_0141.nii.gz saved successfully!
# CTtrain_1_0142.nii.gz saved successfully!
# CTtrain_1_0143.nii.gz saved successfully!
# CTtrain_1_0144.nii.gz saved successfully!
# CTtrain_1_0145.nii.gz saved successfully!
# CTtrain_1_0146.nii.gz saved successfully!
# CTtrain_1_0147.nii.gz saved successfully!
# CTtrain_1_0148.nii.gz saved successfully!
# CTtrain_1_0149.nii.gz saved successfully!
# CTtrain_1_0150.nii.gz saved successfully!
# CTtrain_1_0151.nii.gz saved successfully!
# CTtrain_1_0152.nii.gz saved successfully!
# CTtrain_1_0153.nii.gz saved successfully!
# CTtrain_1_0154.nii.gz saved successfully!
# CTtrain_1_0155.nii.gz saved successfully!
# CTtrain_1_0156.nii.gz saved successfully!
# CTtrain_1_0157.nii.gz saved successfully!
# CTtrain_1_0158.nii.gz saved successfully!
# CTtrain_1_0159.nii.gz saved successfully!
# CTtrain_1_0160.nii.gz saved successfully!
# CTtrain_1_0161.nii.gz saved successfully!
# CTtrain_1_0162.nii.gz saved successfully!
# CTtrain_1_0163.nii.gz saved successfully!
# CTtrain_1_0164.nii.gz saved successfully!
# CTtrain_1_0165.nii.gz saved successfully!
# CTtrain_1_0166.nii.gz saved successfully!
# CTtrain_1_0167.nii.gz saved successfully!
# CTtrain_1_0168.nii.gz saved successfully!
# CTtrain_1_0169.nii.gz saved successfully!
# CTtrain_1_0170.nii.gz saved successfully!
# CTtrain_1_0171.nii.gz saved successfully!
# CTtrain_1_0172.nii.gz saved successfully!
# CTtrain_1_0173.nii.gz saved successfully!
# CTtrain_1_0174.nii.gz saved successfully!
# CTtrain_1_0175.nii.gz saved successfully!
# CTtrain_1_0176.nii.gz saved successfully!
# CTtrain_1_0177.nii.gz saved successfully!
# CTtrain_1_0178.nii.gz saved successfully!
# CTtrain_1_0179.nii.gz saved successfully!
# CTtrain_1_0180.nii.gz saved successfully!
# CTtrain_1_0181.nii.gz saved successfully!
# CTtrain_1_0182.nii.gz saved successfully!
# CTtrain_1_0183.nii.gz saved successfully!
# CTtrain_1_0184.nii.gz saved successfully!
# CTtrain_1_0185.nii.gz saved successfully!
# CTtrain_1_0186.nii.gz saved successfully!
# CTtrain_1_0187.nii.gz saved successfully!
# CTtrain_1_0188.nii.gz saved successfully!
# CTtrain_1_0189.nii.gz saved successfully!
# CTtrain_1_0190.nii.gz saved successfully!
# CTtrain_1_0191.nii.gz saved successfully!
# CTtrain_1_0192.nii.gz saved successfully!
# CTtrain_1_0193.nii.gz saved successfully!
# CTtrain_1_0194.nii.gz saved successfully!
# CTtrain_1_0195.nii.gz saved successfully!
# CTtrain_1_0196.nii.gz saved successfully!
# CTtrain_1_0197.nii.gz saved successfully!
# CTtrain_1_0198.nii.gz saved successfully!
# CTtrain_1_0199.nii.gz saved successfully!
# CTtrain_1_0200.nii.gz saved successfully!
# CTtrain_1_0201.nii.gz saved successfully!
# CTtrain_1_0202.nii.gz saved successfully!
# CTtrain_1_0203.nii.gz saved successfully!
# CTtrain_1_0204.nii.gz saved successfully!
# CTtrain_1_0205.nii.gz saved successfully!
# CTtrain_1_0206.nii.gz saved successfully!
# CTtrain_1_0207.nii.gz saved successfully!
# CTtrain_1_0208.nii.gz saved successfully!
# CTtrain_1_0209.nii.gz saved successfully!
# CTtrain_1_0210.nii.gz saved successfully!
# CTtrain_1_0211.nii.gz saved successfully!
# CTtrain_1_0212.nii.gz saved successfully!
# CTtrain_1_0213.nii.gz saved successfully!
# CTtrain_1_0214.nii.gz saved successfully!
# CTtrain_1_0215.nii.gz saved successfully!
# CTtrain_1_0216.nii.gz saved successfully!
# CTtrain_1_0217.nii.gz saved successfully!
# CTtrain_1_0218.nii.gz saved successfully!
# CTtrain_1_0219.nii.gz saved successfully!
# CTtrain_1_0220.nii.gz saved successfully!
# CTtrain_1_0221.nii.gz saved successfully!
# CTtrain_1_0222.nii.gz saved successfully!
# CTtrain_1_0223.nii.gz saved successfully!
# CTtrain_1_0224.nii.gz saved successfully!
# CTtrain_1_0225.nii.gz saved successfully!
# CTtrain_1_0226.nii.gz saved successfully!
# CTtrain_1_0227.nii.gz saved successfully!
# CTtrain_1_0228.nii.gz saved successfully!
# CTtrain_1_0229.nii.gz saved successfully!
# CTtrain_1_0230.nii.gz saved successfully!
# CTtrain_1_0231.nii.gz saved successfully!
# CTtrain_1_0232.nii.gz saved successfully!
# CTtrain_1_0233.nii.gz saved successfully!
# CTtrain_1_0234.nii.gz saved successfully!
# CTtrain_1_0235.nii.gz saved successfully!
# CTtrain_1_0236.nii.gz saved successfully!
# CTtrain_1_0237.nii.gz saved successfully!
# CTtrain_1_0238.nii.gz saved successfully!
# CTtrain_1_0239.nii.gz saved successfully!
# CTtrain_1_0240.nii.gz saved successfully!
# CTtrain_1_0241.nii.gz saved successfully!
# CTtrain_1_0242.nii.gz saved successfully!
# CTtrain_1_0243.nii.gz saved successfully!
# CTtrain_1_0244.nii.gz saved successfully!
# CTtrain_1_0245.nii.gz saved successfully!
# CTtrain_1_0246.nii.gz saved successfully!
# CTtrain_1_0247.nii.gz saved successfully!
# CTtrain_1_0248.nii.gz saved successfully!
# CTtrain_1_0249.nii.gz saved successfully!
# CTtrain_1_0250.nii.gz saved successfully!
# CTtrain_1_0251.nii.gz saved successfully!
# CTtrain_1_0252.nii.gz saved successfully!
# CTtrain_1_0253.nii.gz saved successfully!
# CTtrain_1_0254.nii.gz saved successfully!
# CTtrain_1_0255.nii.gz saved successfully!
# CTtrain_1_0256.nii.gz saved successfully!
# CTtrain_1_0257.nii.gz saved successfully!
# CTtrain_1_0258.nii.gz saved successfully!
# CTtrain_1_0259.nii.gz saved successfully!
# CTtrain_1_0260.nii.gz saved successfully!
# CTtrain_1_0261.nii.gz saved successfully!
# CTtrain_1_0262.nii.gz saved successfully!
# CTtrain_1_0263.nii.gz saved successfully!
# CTtrain_1_0264.nii.gz saved successfully!
# CTtrain_1_0265.nii.gz saved successfully!
# CTtrain_1_0266.nii.gz saved successfully!
# CTtrain_1_0267.nii.gz saved successfully!
# CTtrain_1_0268.nii.gz saved successfully!
# CTtrain_1_0269.nii.gz saved successfully!
# CTtrain_1_0270.nii.gz saved successfully!
# CTtrain_1_0271.nii.gz saved successfully!
# CTtrain_1_0272.nii.gz saved successfully!
# CTtrain_1_0273.nii.gz saved successfully!
# CTtrain_1_0274.nii.gz saved successfully!
# CTtrain_1_0275.nii.gz saved successfully!
# CTtrain_1_0276.nii.gz saved successfully!
# CTtrain_1_0277.nii.gz saved successfully!
# CTtrain_1_0278.nii.gz saved successfully!
# CTtrain_1_0279.nii.gz saved successfully!
# CTtrain_1_0280.nii.gz saved successfully!
# CTtrain_1_0281.nii.gz saved successfully!
# CTtrain_1_0282.nii.gz saved successfully!
# CTtrain_1_0283.nii.gz saved successfully!
# CTtrain_1_0284.nii.gz saved successfully!
# CTtrain_1_0285.nii.gz saved successfully!
# CTtrain_1_0286.nii.gz saved successfully!
# CTtrain_1_0287.nii.gz saved successfully!
# CTtrain_1_0288.nii.gz saved successfully!
# CTtrain_1_0289.nii.gz saved successfully!
# CTtrain_1_0290.nii.gz saved successfully!
# CTtrain_1_0291.nii.gz saved successfully!
# CTtrain_1_0292.nii.gz saved successfully!
# CTtrain_1_0293.nii.gz saved successfully!
# CTtrain_1_0294.nii.gz saved successfully!
# CTtrain_1_0295.nii.gz saved successfully!
# CTtrain_1_0296.nii.gz saved successfully!
# CTtrain_1_0297.nii.gz saved successfully!
# CTtrain_1_0298.nii.gz saved successfully!
# CTtrain_1_0299.nii.gz saved successfully!
# CTtrain_1_0300.nii.gz saved successfully!
# CTtrain_1_0301.nii.gz saved successfully!
# CTtrain_1_0302.nii.gz saved successfully!
# CTtrain_1_0303.nii.gz saved successfully!
# CTtrain_1_0304.nii.gz saved successfully!
# CTtrain_1_0305.nii.gz saved successfully!
# CTtrain_1_0306.nii.gz saved successfully!
# CTtrain_1_0307.nii.gz saved successfully!
# CTtrain_1_0308.nii.gz saved successfully!
# CTtrain_1_0309.nii.gz saved successfully!
# CTtrain_1_0310.nii.gz saved successfully!
# CTtrain_1_0311.nii.gz saved successfully!
# CTtrain_1_0312.nii.gz saved successfully!
# CTtrain_1_0313.nii.gz saved successfully!
# CTtrain_1_0314.nii.gz saved successfully!
# CTtrain_1_0315.nii.gz saved successfully!
# CTtrain_1_0316.nii.gz saved successfully!
# CTtrain_1_0317.nii.gz saved successfully!
# CTtrain_1_0318.nii.gz saved successfully!
# CTtrain_1_0319.nii.gz saved successfully!
# CTtrain_1_0320.nii.gz saved successfully!
# CTtrain_1_0321.nii.gz saved successfully!
# CTtrain_1_0322.nii.gz saved successfully!
# CTtrain_1_0323.nii.gz saved successfully!
# CTtrain_1_0324.nii.gz saved successfully!
# CTtrain_1_0325.nii.gz saved successfully!
# CTtrain_1_0326.nii.gz saved successfully!
# CTtrain_1_0327.nii.gz saved successfully!
# CTtrain_1_0328.nii.gz saved successfully!
# CTtrain_1_0329.nii.gz saved successfully!
# CTtrain_1_0330.nii.gz saved successfully!
# CTtrain_1_0331.nii.gz saved successfully!
# CTtrain_1_0332.nii.gz saved successfully!
# CTtrain_1_0333.nii.gz saved successfully!
# CTtrain_1_0334.nii.gz saved successfully!
# CTtrain_1_0335.nii.gz saved successfully!
# CTtrain_1_0336.nii.gz saved successfully!
# CTtrain_1_0337.nii.gz saved successfully!
# CTtrain_1_0338.nii.gz saved successfully!
# CTtrain_1_0339.nii.gz saved successfully!
# CTtrain_1_0340.nii.gz saved successfully!
# CTtrain_1_0341.nii.gz saved successfully!
# CTtrain_1_0342.nii.gz saved successfully!
# CTtrain_1_0343.nii.gz saved successfully!
# CTtrain_1_0344.nii.gz saved successfully!
# CTtrain_1_0345.nii.gz saved successfully!
# CTtrain_1_0346.nii.gz saved successfully!
# CTtrain_1_0347.nii.gz saved successfully!
# CTtrain_1_0348.nii.gz saved successfully!
# CTtrain_1_0349.nii.gz saved successfully!
# CTtrain_1_0350.nii.gz saved successfully!
# CTtrain_1_0351.nii.gz saved successfully!
# CTtrain_1_0352.nii.gz saved successfully!
# CTtrain_1_0353.nii.gz saved successfully!
# CTtrain_1_0354.nii.gz saved successfully!
# CTtrain_1_0355.nii.gz saved successfully!
# CTtrain_1_0356.nii.gz saved successfully!
# CTtrain_1_0357.nii.gz saved successfully!
# CTtrain_1_0358.nii.gz saved successfully!
# CTtrain_1_0359.nii.gz saved successfully!
# CTtrain_1_0360.nii.gz saved successfully!
# CTtrain_1_0361.nii.gz saved successfully!
# CTtrain_1_0362.nii.gz saved successfully!
# CTtrain_1_0363.nii.gz saved successfully!
# CTtrain_1_0364.nii.gz saved successfully!
# CTtrain_1_0365.nii.gz saved successfully!
# CTtrain_1_0366.nii.gz saved successfully!
# CTtrain_1_0367.nii.gz saved successfully!
# CTtrain_1_0368.nii.gz saved successfully!
# CTtrain_1_0369.nii.gz saved successfully!
# CTtrain_1_0370.nii.gz saved successfully!
# CTtrain_1_0371.nii.gz saved successfully!
# CTtrain_1_0372.nii.gz saved successfully!
# CTtrain_1_0373.nii.gz saved successfully!
# CTtrain_1_0374.nii.gz saved successfully!
# CTtrain_1_0375.nii.gz saved successfully!
# CTtrain_1_0376.nii.gz saved successfully!
# CTtrain_1_0377.nii.gz saved successfully!
# CTtrain_1_0378.nii.gz saved successfully!
# CTtrain_1_0379.nii.gz saved successfully!
# CTtrain_1_0380.nii.gz saved successfully!
# CTtrain_1_0381.nii.gz saved successfully!
# CTtrain_1_0382.nii.gz saved successfully!
# CTtrain_1_0383.nii.gz saved successfully!
# CTtrain_1_0384.nii.gz saved successfully!
# CTlabel_1_0001.nii.gz saved successfully!
# CTlabel_1_0002.nii.gz saved successfully!
# CTlabel_1_0003.nii.gz saved successfully!
# CTlabel_1_0004.nii.gz saved successfully!
# CTlabel_1_0005.nii.gz saved successfully!
# CTlabel_1_0006.nii.gz saved successfully!
# CTlabel_1_0007.nii.gz saved successfully!
# CTlabel_1_0008.nii.gz saved successfully!
# CTlabel_1_0009.nii.gz saved successfully!
# CTlabel_1_0010.nii.gz saved successfully!
# CTlabel_1_0011.nii.gz saved successfully!
# CTlabel_1_0012.nii.gz saved successfully!
# CTlabel_1_0013.nii.gz saved successfully!
# CTlabel_1_0014.nii.gz saved successfully!
# CTlabel_1_0015.nii.gz saved successfully!
# CTlabel_1_0016.nii.gz saved successfully!
# CTlabel_1_0017.nii.gz saved successfully!
# CTlabel_1_0018.nii.gz saved successfully!
# CTlabel_1_0019.nii.gz saved successfully!
# CTlabel_1_0020.nii.gz saved successfully!
# CTlabel_1_0021.nii.gz saved successfully!
# CTlabel_1_0022.nii.gz saved successfully!
# CTlabel_1_0023.nii.gz saved successfully!
# CTlabel_1_0024.nii.gz saved successfully!
# CTlabel_1_0025.nii.gz saved successfully!
# CTlabel_1_0026.nii.gz saved successfully!
# CTlabel_1_0027.nii.gz saved successfully!
# CTlabel_1_0028.nii.gz saved successfully!
# CTlabel_1_0029.nii.gz saved successfully!
# CTlabel_1_0030.nii.gz saved successfully!
# CTlabel_1_0031.nii.gz saved successfully!
# CTlabel_1_0032.nii.gz saved successfully!
# CTlabel_1_0033.nii.gz saved successfully!
# CTlabel_1_0034.nii.gz saved successfully!
# CTlabel_1_0035.nii.gz saved successfully!
# CTlabel_1_0036.nii.gz saved successfully!
# CTlabel_1_0037.nii.gz saved successfully!
# CTlabel_1_0038.nii.gz saved successfully!
# CTlabel_1_0039.nii.gz saved successfully!
# CTlabel_1_0040.nii.gz saved successfully!
# CTlabel_1_0041.nii.gz saved successfully!
# CTlabel_1_0042.nii.gz saved successfully!
# CTlabel_1_0043.nii.gz saved successfully!
# CTlabel_1_0044.nii.gz saved successfully!
# CTlabel_1_0045.nii.gz saved successfully!
# CTlabel_1_0046.nii.gz saved successfully!
# CTlabel_1_0047.nii.gz saved successfully!
# CTlabel_1_0048.nii.gz saved successfully!
# CTlabel_1_0049.nii.gz saved successfully!
# CTlabel_1_0050.nii.gz saved successfully!
# CTlabel_1_0051.nii.gz saved successfully!
# CTlabel_1_0052.nii.gz saved successfully!
# CTlabel_1_0053.nii.gz saved successfully!
# CTlabel_1_0054.nii.gz saved successfully!
# CTlabel_1_0055.nii.gz saved successfully!
# CTlabel_1_0056.nii.gz saved successfully!
# CTlabel_1_0057.nii.gz saved successfully!
# CTlabel_1_0058.nii.gz saved successfully!
# CTlabel_1_0059.nii.gz saved successfully!
# CTlabel_1_0060.nii.gz saved successfully!
# CTlabel_1_0061.nii.gz saved successfully!
# CTlabel_1_0062.nii.gz saved successfully!
# CTlabel_1_0063.nii.gz saved successfully!
# CTlabel_1_0064.nii.gz saved successfully!
# CTlabel_1_0065.nii.gz saved successfully!
# CTlabel_1_0066.nii.gz saved successfully!
# CTlabel_1_0067.nii.gz saved successfully!
# CTlabel_1_0068.nii.gz saved successfully!
# CTlabel_1_0069.nii.gz saved successfully!
# CTlabel_1_0070.nii.gz saved successfully!
# CTlabel_1_0071.nii.gz saved successfully!
# CTlabel_1_0072.nii.gz saved successfully!
# CTlabel_1_0073.nii.gz saved successfully!
# CTlabel_1_0074.nii.gz saved successfully!
# CTlabel_1_0075.nii.gz saved successfully!
# CTlabel_1_0076.nii.gz saved successfully!
# CTlabel_1_0077.nii.gz saved successfully!
# CTlabel_1_0078.nii.gz saved successfully!
# CTlabel_1_0079.nii.gz saved successfully!
# CTlabel_1_0080.nii.gz saved successfully!
# CTlabel_1_0081.nii.gz saved successfully!
# CTlabel_1_0082.nii.gz saved successfully!
# CTlabel_1_0083.nii.gz saved successfully!
# CTlabel_1_0084.nii.gz saved successfully!
# CTlabel_1_0085.nii.gz saved successfully!
# CTlabel_1_0086.nii.gz saved successfully!
# CTlabel_1_0087.nii.gz saved successfully!
# CTlabel_1_0088.nii.gz saved successfully!
# CTlabel_1_0089.nii.gz saved successfully!
# CTlabel_1_0090.nii.gz saved successfully!
# CTlabel_1_0091.nii.gz saved successfully!
# CTlabel_1_0092.nii.gz saved successfully!
# CTlabel_1_0093.nii.gz saved successfully!
# CTlabel_1_0094.nii.gz saved successfully!
# CTlabel_1_0095.nii.gz saved successfully!
# CTlabel_1_0096.nii.gz saved successfully!
# CTlabel_1_0097.nii.gz saved successfully!
# CTlabel_1_0098.nii.gz saved successfully!
# CTlabel_1_0099.nii.gz saved successfully!
# CTlabel_1_0100.nii.gz saved successfully!
# CTlabel_1_0101.nii.gz saved successfully!
# CTlabel_1_0102.nii.gz saved successfully!
# CTlabel_1_0103.nii.gz saved successfully!
# CTlabel_1_0104.nii.gz saved successfully!
# CTlabel_1_0105.nii.gz saved successfully!
# CTlabel_1_0106.nii.gz saved successfully!
# CTlabel_1_0107.nii.gz saved successfully!
# CTlabel_1_0108.nii.gz saved successfully!
# CTlabel_1_0109.nii.gz saved successfully!
# CTlabel_1_0110.nii.gz saved successfully!
# CTlabel_1_0111.nii.gz saved successfully!
# CTlabel_1_0112.nii.gz saved successfully!
# CTlabel_1_0113.nii.gz saved successfully!
# CTlabel_1_0114.nii.gz saved successfully!
# CTlabel_1_0115.nii.gz saved successfully!
# CTlabel_1_0116.nii.gz saved successfully!
# CTlabel_1_0117.nii.gz saved successfully!
# CTlabel_1_0118.nii.gz saved successfully!
# CTlabel_1_0119.nii.gz saved successfully!
# CTlabel_1_0120.nii.gz saved successfully!
# CTlabel_1_0121.nii.gz saved successfully!
# CTlabel_1_0122.nii.gz saved successfully!
# CTlabel_1_0123.nii.gz saved successfully!
# CTlabel_1_0124.nii.gz saved successfully!
# CTlabel_1_0125.nii.gz saved successfully!
# CTlabel_1_0126.nii.gz saved successfully!
# CTlabel_1_0127.nii.gz saved successfully!
# CTlabel_1_0128.nii.gz saved successfully!
# CTlabel_1_0129.nii.gz saved successfully!
# CTlabel_1_0130.nii.gz saved successfully!
# CTlabel_1_0131.nii.gz saved successfully!
# CTlabel_1_0132.nii.gz saved successfully!
# CTlabel_1_0133.nii.gz saved successfully!
# CTlabel_1_0134.nii.gz saved successfully!
# CTlabel_1_0135.nii.gz saved successfully!
# CTlabel_1_0136.nii.gz saved successfully!
# CTlabel_1_0137.nii.gz saved successfully!
# CTlabel_1_0138.nii.gz saved successfully!
# CTlabel_1_0139.nii.gz saved successfully!
# CTlabel_1_0140.nii.gz saved successfully!
# CTlabel_1_0141.nii.gz saved successfully!
# CTlabel_1_0142.nii.gz saved successfully!
# CTlabel_1_0143.nii.gz saved successfully!
# CTlabel_1_0144.nii.gz saved successfully!
# CTlabel_1_0145.nii.gz saved successfully!
# CTlabel_1_0146.nii.gz saved successfully!
# CTlabel_1_0147.nii.gz saved successfully!
# CTlabel_1_0148.nii.gz saved successfully!
# CTlabel_1_0149.nii.gz saved successfully!
# CTlabel_1_0150.nii.gz saved successfully!
# CTlabel_1_0151.nii.gz saved successfully!
# CTlabel_1_0152.nii.gz saved successfully!
# CTlabel_1_0153.nii.gz saved successfully!
# CTlabel_1_0154.nii.gz saved successfully!
# CTlabel_1_0155.nii.gz saved successfully!
# CTlabel_1_0156.nii.gz saved successfully!
# CTlabel_1_0157.nii.gz saved successfully!
# CTlabel_1_0158.nii.gz saved successfully!
# CTlabel_1_0159.nii.gz saved successfully!
# CTlabel_1_0160.nii.gz saved successfully!
# CTlabel_1_0161.nii.gz saved successfully!
# CTlabel_1_0162.nii.gz saved successfully!
# CTlabel_1_0163.nii.gz saved successfully!
# CTlabel_1_0164.nii.gz saved successfully!
# CTlabel_1_0165.nii.gz saved successfully!
# CTlabel_1_0166.nii.gz saved successfully!
# CTlabel_1_0167.nii.gz saved successfully!
# CTlabel_1_0168.nii.gz saved successfully!
# CTlabel_1_0169.nii.gz saved successfully!
# CTlabel_1_0170.nii.gz saved successfully!
# CTlabel_1_0171.nii.gz saved successfully!
# CTlabel_1_0172.nii.gz saved successfully!
# CTlabel_1_0173.nii.gz saved successfully!
# CTlabel_1_0174.nii.gz saved successfully!
# CTlabel_1_0175.nii.gz saved successfully!
# CTlabel_1_0176.nii.gz saved successfully!
# CTlabel_1_0177.nii.gz saved successfully!
# CTlabel_1_0178.nii.gz saved successfully!
# CTlabel_1_0179.nii.gz saved successfully!
# CTlabel_1_0180.nii.gz saved successfully!
# CTlabel_1_0181.nii.gz saved successfully!
# CTlabel_1_0182.nii.gz saved successfully!
# CTlabel_1_0183.nii.gz saved successfully!
# CTlabel_1_0184.nii.gz saved successfully!
# CTlabel_1_0185.nii.gz saved successfully!
# CTlabel_1_0186.nii.gz saved successfully!
# CTlabel_1_0187.nii.gz saved successfully!
# CTlabel_1_0188.nii.gz saved successfully!
# CTlabel_1_0189.nii.gz saved successfully!
# CTlabel_1_0190.nii.gz saved successfully!
# CTlabel_1_0191.nii.gz saved successfully!
# CTlabel_1_0192.nii.gz saved successfully!
# CTlabel_1_0193.nii.gz saved successfully!
# CTlabel_1_0194.nii.gz saved successfully!
# CTlabel_1_0195.nii.gz saved successfully!
# CTlabel_1_0196.nii.gz saved successfully!
# CTlabel_1_0197.nii.gz saved successfully!
# CTlabel_1_0198.nii.gz saved successfully!
# CTlabel_1_0199.nii.gz saved successfully!
# CTlabel_1_0200.nii.gz saved successfully!
# CTlabel_1_0201.nii.gz saved successfully!
# CTlabel_1_0202.nii.gz saved successfully!
# CTlabel_1_0203.nii.gz saved successfully!
# CTlabel_1_0204.nii.gz saved successfully!
# CTlabel_1_0205.nii.gz saved successfully!
# CTlabel_1_0206.nii.gz saved successfully!
# CTlabel_1_0207.nii.gz saved successfully!
# CTlabel_1_0208.nii.gz saved successfully!
# CTlabel_1_0209.nii.gz saved successfully!
# CTlabel_1_0210.nii.gz saved successfully!
# CTlabel_1_0211.nii.gz saved successfully!
# CTlabel_1_0212.nii.gz saved successfully!
# CTlabel_1_0213.nii.gz saved successfully!
# CTlabel_1_0214.nii.gz saved successfully!
# CTlabel_1_0215.nii.gz saved successfully!
# CTlabel_1_0216.nii.gz saved successfully!
# CTlabel_1_0217.nii.gz saved successfully!
# CTlabel_1_0218.nii.gz saved successfully!
# CTlabel_1_0219.nii.gz saved successfully!
# CTlabel_1_0220.nii.gz saved successfully!
# CTlabel_1_0221.nii.gz saved successfully!
# CTlabel_1_0222.nii.gz saved successfully!
# CTlabel_1_0223.nii.gz saved successfully!
# CTlabel_1_0224.nii.gz saved successfully!
# CTlabel_1_0225.nii.gz saved successfully!
# CTlabel_1_0226.nii.gz saved successfully!
# CTlabel_1_0227.nii.gz saved successfully!
# CTlabel_1_0228.nii.gz saved successfully!
# CTlabel_1_0229.nii.gz saved successfully!
# CTlabel_1_0230.nii.gz saved successfully!
# CTlabel_1_0231.nii.gz saved successfully!
# CTlabel_1_0232.nii.gz saved successfully!
# CTlabel_1_0233.nii.gz saved successfully!
# CTlabel_1_0234.nii.gz saved successfully!
# CTlabel_1_0235.nii.gz saved successfully!
# CTlabel_1_0236.nii.gz saved successfully!
# CTlabel_1_0237.nii.gz saved successfully!
# CTlabel_1_0238.nii.gz saved successfully!
# CTlabel_1_0239.nii.gz saved successfully!
# CTlabel_1_0240.nii.gz saved successfully!
# CTlabel_1_0241.nii.gz saved successfully!
# CTlabel_1_0242.nii.gz saved successfully!
# CTlabel_1_0243.nii.gz saved successfully!
# CTlabel_1_0244.nii.gz saved successfully!
# CTlabel_1_0245.nii.gz saved successfully!
# CTlabel_1_0246.nii.gz saved successfully!
# CTlabel_1_0247.nii.gz saved successfully!
# CTlabel_1_0248.nii.gz saved successfully!
# CTlabel_1_0249.nii.gz saved successfully!
# CTlabel_1_0250.nii.gz saved successfully!
# CTlabel_1_0251.nii.gz saved successfully!
# CTlabel_1_0252.nii.gz saved successfully!
# CTlabel_1_0253.nii.gz saved successfully!
# CTlabel_1_0254.nii.gz saved successfully!
# CTlabel_1_0255.nii.gz saved successfully!
# CTlabel_1_0256.nii.gz saved successfully!
# CTlabel_1_0257.nii.gz saved successfully!
# CTlabel_1_0258.nii.gz saved successfully!
# CTlabel_1_0259.nii.gz saved successfully!
# CTlabel_1_0260.nii.gz saved successfully!
# CTlabel_1_0261.nii.gz saved successfully!
# CTlabel_1_0262.nii.gz saved successfully!
# CTlabel_1_0263.nii.gz saved successfully!
# CTlabel_1_0264.nii.gz saved successfully!
# CTlabel_1_0265.nii.gz saved successfully!
# CTlabel_1_0266.nii.gz saved successfully!
# CTlabel_1_0267.nii.gz saved successfully!
# CTlabel_1_0268.nii.gz saved successfully!
# CTlabel_1_0269.nii.gz saved successfully!
# CTlabel_1_0270.nii.gz saved successfully!
# CTlabel_1_0271.nii.gz saved successfully!
# CTlabel_1_0272.nii.gz saved successfully!
# CTlabel_1_0273.nii.gz saved successfully!
# CTlabel_1_0274.nii.gz saved successfully!
# CTlabel_1_0275.nii.gz saved successfully!
# CTlabel_1_0276.nii.gz saved successfully!
# CTlabel_1_0277.nii.gz saved successfully!
# CTlabel_1_0278.nii.gz saved successfully!
# CTlabel_1_0279.nii.gz saved successfully!
# CTlabel_1_0280.nii.gz saved successfully!
# CTlabel_1_0281.nii.gz saved successfully!
# CTlabel_1_0282.nii.gz saved successfully!
# CTlabel_1_0283.nii.gz saved successfully!
# CTlabel_1_0284.nii.gz saved successfully!
# CTlabel_1_0285.nii.gz saved successfully!
# CTlabel_1_0286.nii.gz saved successfully!
# CTlabel_1_0287.nii.gz saved successfully!
# CTlabel_1_0288.nii.gz saved successfully!
# CTlabel_1_0289.nii.gz saved successfully!
# CTlabel_1_0290.nii.gz saved successfully!
# CTlabel_1_0291.nii.gz saved successfully!
# CTlabel_1_0292.nii.gz saved successfully!
# CTlabel_1_0293.nii.gz saved successfully!
# CTlabel_1_0294.nii.gz saved successfully!
# CTlabel_1_0295.nii.gz saved successfully!
# CTlabel_1_0296.nii.gz saved successfully!
# CTlabel_1_0297.nii.gz saved successfully!
# CTlabel_1_0298.nii.gz saved successfully!
# CTlabel_1_0299.nii.gz saved successfully!
# CTlabel_1_0300.nii.gz saved successfully!
# CTlabel_1_0301.nii.gz saved successfully!
# CTlabel_1_0302.nii.gz saved successfully!
# CTlabel_1_0303.nii.gz saved successfully!
# CTlabel_1_0304.nii.gz saved successfully!
# CTlabel_1_0305.nii.gz saved successfully!
# CTlabel_1_0306.nii.gz saved successfully!
# CTlabel_1_0307.nii.gz saved successfully!
# CTlabel_1_0308.nii.gz saved successfully!
# CTlabel_1_0309.nii.gz saved successfully!
# CTlabel_1_0310.nii.gz saved successfully!
# CTlabel_1_0311.nii.gz saved successfully!
# CTlabel_1_0312.nii.gz saved successfully!
# CTlabel_1_0313.nii.gz saved successfully!
# CTlabel_1_0314.nii.gz saved successfully!
# CTlabel_1_0315.nii.gz saved successfully!
# CTlabel_1_0316.nii.gz saved successfully!
# CTlabel_1_0317.nii.gz saved successfully!
# CTlabel_1_0318.nii.gz saved successfully!
# CTlabel_1_0319.nii.gz saved successfully!
# CTlabel_1_0320.nii.gz saved successfully!
# CTlabel_1_0321.nii.gz saved successfully!
# CTlabel_1_0322.nii.gz saved successfully!
# CTlabel_1_0323.nii.gz saved successfully!
# CTlabel_1_0324.nii.gz saved successfully!
# CTlabel_1_0325.nii.gz saved successfully!
# CTlabel_1_0326.nii.gz saved successfully!
# CTlabel_1_0327.nii.gz saved successfully!
# CTlabel_1_0328.nii.gz saved successfully!
# CTlabel_1_0329.nii.gz saved successfully!
# CTlabel_1_0330.nii.gz saved successfully!
# CTlabel_1_0331.nii.gz saved successfully!
# CTlabel_1_0332.nii.gz saved successfully!
# CTlabel_1_0333.nii.gz saved successfully!
# CTlabel_1_0334.nii.gz saved successfully!
# CTlabel_1_0335.nii.gz saved successfully!
# CTlabel_1_0336.nii.gz saved successfully!
# CTlabel_1_0337.nii.gz saved successfully!
# CTlabel_1_0338.nii.gz saved successfully!
# CTlabel_1_0339.nii.gz saved successfully!
# CTlabel_1_0340.nii.gz saved successfully!
# CTlabel_1_0341.nii.gz saved successfully!
# CTlabel_1_0342.nii.gz saved successfully!
# CTlabel_1_0343.nii.gz saved successfully!
# CTlabel_1_0344.nii.gz saved successfully!
# CTlabel_1_0345.nii.gz saved successfully!
# CTlabel_1_0346.nii.gz saved successfully!
# CTlabel_1_0347.nii.gz saved successfully!
# CTlabel_1_0348.nii.gz saved successfully!
# CTlabel_1_0349.nii.gz saved successfully!
# CTlabel_1_0350.nii.gz saved successfully!
# CTlabel_1_0351.nii.gz saved successfully!
# CTlabel_1_0352.nii.gz saved successfully!
# CTlabel_1_0353.nii.gz saved successfully!
# CTlabel_1_0354.nii.gz saved successfully!
# CTlabel_1_0355.nii.gz saved successfully!
# CTlabel_1_0356.nii.gz saved successfully!
# CTlabel_1_0357.nii.gz saved successfully!
# CTlabel_1_0358.nii.gz saved successfully!
# CTlabel_1_0359.nii.gz saved successfully!
# CTlabel_1_0360.nii.gz saved successfully!
# CTlabel_1_0361.nii.gz saved successfully!
# CTlabel_1_0362.nii.gz saved successfully!
# CTlabel_1_0363.nii.gz saved successfully!
# CTlabel_1_0364.nii.gz saved successfully!
# CTlabel_1_0365.nii.gz saved successfully!
# CTlabel_1_0366.nii.gz saved successfully!
# CTlabel_1_0367.nii.gz saved successfully!
# CTlabel_1_0368.nii.gz saved successfully!
# CTlabel_1_0369.nii.gz saved successfully!
# CTlabel_1_0370.nii.gz saved successfully!
# CTlabel_1_0371.nii.gz saved successfully!
# CTlabel_1_0372.nii.gz saved successfully!
# CTlabel_1_0373.nii.gz saved successfully!
# CTlabel_1_0374.nii.gz saved successfully!
# CTlabel_1_0375.nii.gz saved successfully!
# CTlabel_1_0376.nii.gz saved successfully!
# CTlabel_1_0377.nii.gz saved successfully!
# CTlabel_1_0378.nii.gz saved successfully!
# CTlabel_1_0379.nii.gz saved successfully!
# CTlabel_1_0380.nii.gz saved successfully!
# CTlabel_1_0381.nii.gz saved successfully!
# CTlabel_1_0382.nii.gz saved successfully!
# CTlabel_1_0383.nii.gz saved successfully!
# CTlabel_1_0384.nii.gz saved successfully!
# CTtrain_2_0001.nii.gz saved successfully!
# CTtrain_2_0002.nii.gz saved successfully!
# CTtrain_2_0003.nii.gz saved successfully!
# CTtrain_2_0004.nii.gz saved successfully!
# CTtrain_2_0005.nii.gz saved successfully!
# CTtrain_2_0006.nii.gz saved successfully!
# CTtrain_2_0007.nii.gz saved successfully!
# CTtrain_2_0008.nii.gz saved successfully!
# CTtrain_2_0009.nii.gz saved successfully!
# CTtrain_2_0010.nii.gz saved successfully!
# CTtrain_2_0011.nii.gz saved successfully!
# CTtrain_2_0012.nii.gz saved successfully!
# CTtrain_2_0013.nii.gz saved successfully!
# CTtrain_2_0014.nii.gz saved successfully!
# CTtrain_2_0015.nii.gz saved successfully!
# CTtrain_2_0016.nii.gz saved successfully!
# CTtrain_2_0017.nii.gz saved successfully!
# CTtrain_2_0018.nii.gz saved successfully!
# CTtrain_2_0019.nii.gz saved successfully!
# CTtrain_2_0020.nii.gz saved successfully!
# CTtrain_2_0021.nii.gz saved successfully!
# CTtrain_2_0022.nii.gz saved successfully!
# CTtrain_2_0023.nii.gz saved successfully!
# CTtrain_2_0024.nii.gz saved successfully!
# CTtrain_2_0025.nii.gz saved successfully!
# CTtrain_2_0026.nii.gz saved successfully!
# CTtrain_2_0027.nii.gz saved successfully!
# CTtrain_2_0028.nii.gz saved successfully!
# CTtrain_2_0029.nii.gz saved successfully!
# CTtrain_2_0030.nii.gz saved successfully!
# CTtrain_2_0031.nii.gz saved successfully!
# CTtrain_2_0032.nii.gz saved successfully!
# CTtrain_2_0033.nii.gz saved successfully!
# CTtrain_2_0034.nii.gz saved successfully!
# CTtrain_2_0035.nii.gz saved successfully!
# CTtrain_2_0036.nii.gz saved successfully!
# CTtrain_2_0037.nii.gz saved successfully!
# CTtrain_2_0038.nii.gz saved successfully!
# CTtrain_2_0039.nii.gz saved successfully!
# CTtrain_2_0040.nii.gz saved successfully!
# CTtrain_2_0041.nii.gz saved successfully!
# CTtrain_2_0042.nii.gz saved successfully!
# CTtrain_2_0043.nii.gz saved successfully!
# CTtrain_2_0044.nii.gz saved successfully!
# CTtrain_2_0045.nii.gz saved successfully!
# CTtrain_2_0046.nii.gz saved successfully!
# CTtrain_2_0047.nii.gz saved successfully!
# CTtrain_2_0048.nii.gz saved successfully!
# CTtrain_2_0049.nii.gz saved successfully!
# CTtrain_2_0050.nii.gz saved successfully!
# CTtrain_2_0051.nii.gz saved successfully!
# CTtrain_2_0052.nii.gz saved successfully!
# CTtrain_2_0053.nii.gz saved successfully!
# CTtrain_2_0054.nii.gz saved successfully!
# CTtrain_2_0055.nii.gz saved successfully!
# CTtrain_2_0056.nii.gz saved successfully!
# CTtrain_2_0057.nii.gz saved successfully!
# CTtrain_2_0058.nii.gz saved successfully!
# CTtrain_2_0059.nii.gz saved successfully!
# CTtrain_2_0060.nii.gz saved successfully!
# CTtrain_2_0061.nii.gz saved successfully!
# CTtrain_2_0062.nii.gz saved successfully!
# CTtrain_2_0063.nii.gz saved successfully!
# CTtrain_2_0064.nii.gz saved successfully!
# CTtrain_2_0065.nii.gz saved successfully!
# CTtrain_2_0066.nii.gz saved successfully!
# CTtrain_2_0067.nii.gz saved successfully!
# CTtrain_2_0068.nii.gz saved successfully!
# CTtrain_2_0069.nii.gz saved successfully!
# CTtrain_2_0070.nii.gz saved successfully!
# CTtrain_2_0071.nii.gz saved successfully!
# CTtrain_2_0072.nii.gz saved successfully!
# CTtrain_2_0073.nii.gz saved successfully!
# CTtrain_2_0074.nii.gz saved successfully!
# CTtrain_2_0075.nii.gz saved successfully!
# CTtrain_2_0076.nii.gz saved successfully!
# CTtrain_2_0077.nii.gz saved successfully!
# CTtrain_2_0078.nii.gz saved successfully!
# CTtrain_2_0079.nii.gz saved successfully!
# CTtrain_2_0080.nii.gz saved successfully!
# CTtrain_2_0081.nii.gz saved successfully!
# CTtrain_2_0082.nii.gz saved successfully!
# CTtrain_2_0083.nii.gz saved successfully!
# CTtrain_2_0084.nii.gz saved successfully!
# CTtrain_2_0085.nii.gz saved successfully!
# CTtrain_2_0086.nii.gz saved successfully!
# CTtrain_2_0087.nii.gz saved successfully!
# CTtrain_2_0088.nii.gz saved successfully!
# CTtrain_2_0089.nii.gz saved successfully!
# CTtrain_2_0090.nii.gz saved successfully!
# CTtrain_2_0091.nii.gz saved successfully!
# CTtrain_2_0092.nii.gz saved successfully!
# CTtrain_2_0093.nii.gz saved successfully!
# CTtrain_2_0094.nii.gz saved successfully!
# CTtrain_2_0095.nii.gz saved successfully!
# CTtrain_2_0096.nii.gz saved successfully!
# CTtrain_2_0097.nii.gz saved successfully!
# CTtrain_2_0098.nii.gz saved successfully!
# CTtrain_2_0099.nii.gz saved successfully!
# CTtrain_2_0100.nii.gz saved successfully!
# CTtrain_2_0101.nii.gz saved successfully!
# CTtrain_2_0102.nii.gz saved successfully!
# CTtrain_2_0103.nii.gz saved successfully!
# CTtrain_2_0104.nii.gz saved successfully!
# CTtrain_2_0105.nii.gz saved successfully!
# CTtrain_2_0106.nii.gz saved successfully!
# CTtrain_2_0107.nii.gz saved successfully!
# CTtrain_2_0108.nii.gz saved successfully!
# CTtrain_2_0109.nii.gz saved successfully!
# CTtrain_2_0110.nii.gz saved successfully!
# CTtrain_2_0111.nii.gz saved successfully!
# CTtrain_2_0112.nii.gz saved successfully!
# CTtrain_2_0113.nii.gz saved successfully!
# CTtrain_2_0114.nii.gz saved successfully!
# CTtrain_2_0115.nii.gz saved successfully!
# CTtrain_2_0116.nii.gz saved successfully!
# CTtrain_2_0117.nii.gz saved successfully!
# CTtrain_2_0118.nii.gz saved successfully!
# CTtrain_2_0119.nii.gz saved successfully!
# CTtrain_2_0120.nii.gz saved successfully!
# CTtrain_2_0121.nii.gz saved successfully!
# CTtrain_2_0122.nii.gz saved successfully!
# CTtrain_2_0123.nii.gz saved successfully!
# CTtrain_2_0124.nii.gz saved successfully!
# CTtrain_2_0125.nii.gz saved successfully!
# CTtrain_2_0126.nii.gz saved successfully!
# CTtrain_2_0127.nii.gz saved successfully!
# CTtrain_2_0128.nii.gz saved successfully!
# CTtrain_2_0129.nii.gz saved successfully!
# CTtrain_2_0130.nii.gz saved successfully!
# CTtrain_2_0131.nii.gz saved successfully!
# CTtrain_2_0132.nii.gz saved successfully!
# CTtrain_2_0133.nii.gz saved successfully!
# CTtrain_2_0134.nii.gz saved successfully!
# CTtrain_2_0135.nii.gz saved successfully!
# CTtrain_2_0136.nii.gz saved successfully!
# CTtrain_2_0137.nii.gz saved successfully!
# CTtrain_2_0138.nii.gz saved successfully!
# CTtrain_2_0139.nii.gz saved successfully!
# CTtrain_2_0140.nii.gz saved successfully!
# CTtrain_2_0141.nii.gz saved successfully!
# CTtrain_2_0142.nii.gz saved successfully!
# CTtrain_2_0143.nii.gz saved successfully!
# CTtrain_2_0144.nii.gz saved successfully!
# CTtrain_2_0145.nii.gz saved successfully!
# CTtrain_2_0146.nii.gz saved successfully!
# CTtrain_2_0147.nii.gz saved successfully!
# CTtrain_2_0148.nii.gz saved successfully!
# CTtrain_2_0149.nii.gz saved successfully!
# CTtrain_2_0150.nii.gz saved successfully!
# CTtrain_2_0151.nii.gz saved successfully!
# CTtrain_2_0152.nii.gz saved successfully!
# CTtrain_2_0153.nii.gz saved successfully!
# CTtrain_2_0154.nii.gz saved successfully!
# CTtrain_2_0155.nii.gz saved successfully!
# CTtrain_2_0156.nii.gz saved successfully!
# CTtrain_2_0157.nii.gz saved successfully!
# CTtrain_2_0158.nii.gz saved successfully!
# CTtrain_2_0159.nii.gz saved successfully!
# CTtrain_2_0160.nii.gz saved successfully!
# CTtrain_2_0161.nii.gz saved successfully!
# CTtrain_2_0162.nii.gz saved successfully!
# CTtrain_2_0163.nii.gz saved successfully!
# CTtrain_2_0164.nii.gz saved successfully!
# CTtrain_2_0165.nii.gz saved successfully!
# CTtrain_2_0166.nii.gz saved successfully!
# CTtrain_2_0167.nii.gz saved successfully!
# CTtrain_2_0168.nii.gz saved successfully!
# CTtrain_2_0169.nii.gz saved successfully!
# CTtrain_2_0170.nii.gz saved successfully!
# CTtrain_2_0171.nii.gz saved successfully!
# CTtrain_2_0172.nii.gz saved successfully!
# CTtrain_2_0173.nii.gz saved successfully!
# CTtrain_2_0174.nii.gz saved successfully!
# CTtrain_2_0175.nii.gz saved successfully!
# CTtrain_2_0176.nii.gz saved successfully!
# CTtrain_2_0177.nii.gz saved successfully!
# CTtrain_2_0178.nii.gz saved successfully!
# CTtrain_2_0179.nii.gz saved successfully!
# CTtrain_2_0180.nii.gz saved successfully!
# CTtrain_2_0181.nii.gz saved successfully!
# CTtrain_2_0182.nii.gz saved successfully!
# CTtrain_2_0183.nii.gz saved successfully!
# CTtrain_2_0184.nii.gz saved successfully!
# CTtrain_2_0185.nii.gz saved successfully!
# CTtrain_2_0186.nii.gz saved successfully!
# CTtrain_2_0187.nii.gz saved successfully!
# CTtrain_2_0188.nii.gz saved successfully!
# CTtrain_2_0189.nii.gz saved successfully!
# CTtrain_2_0190.nii.gz saved successfully!
# CTtrain_2_0191.nii.gz saved successfully!
# CTtrain_2_0192.nii.gz saved successfully!
# CTtrain_2_0193.nii.gz saved successfully!
# CTtrain_2_0194.nii.gz saved successfully!
# CTtrain_2_0195.nii.gz saved successfully!
# CTtrain_2_0196.nii.gz saved successfully!
# CTtrain_2_0197.nii.gz saved successfully!
# CTtrain_2_0198.nii.gz saved successfully!
# CTtrain_2_0199.nii.gz saved successfully!
# CTtrain_2_0200.nii.gz saved successfully!
# CTtrain_2_0201.nii.gz saved successfully!
# CTtrain_2_0202.nii.gz saved successfully!
# CTtrain_2_0203.nii.gz saved successfully!
# CTtrain_2_0204.nii.gz saved successfully!
# CTtrain_2_0205.nii.gz saved successfully!
# CTtrain_2_0206.nii.gz saved successfully!
# CTtrain_2_0207.nii.gz saved successfully!
# CTtrain_2_0208.nii.gz saved successfully!
# CTtrain_2_0209.nii.gz saved successfully!
# CTtrain_2_0210.nii.gz saved successfully!
# CTtrain_2_0211.nii.gz saved successfully!
# CTtrain_2_0212.nii.gz saved successfully!
# CTtrain_2_0213.nii.gz saved successfully!
# CTtrain_2_0214.nii.gz saved successfully!
# CTtrain_2_0215.nii.gz saved successfully!
# CTtrain_2_0216.nii.gz saved successfully!
# CTtrain_2_0217.nii.gz saved successfully!
# CTtrain_2_0218.nii.gz saved successfully!
# CTtrain_2_0219.nii.gz saved successfully!
# CTtrain_2_0220.nii.gz saved successfully!
# CTtrain_2_0221.nii.gz saved successfully!
# CTtrain_2_0222.nii.gz saved successfully!
# CTtrain_2_0223.nii.gz saved successfully!
# CTtrain_2_0224.nii.gz saved successfully!
# CTtrain_2_0225.nii.gz saved successfully!
# CTtrain_2_0226.nii.gz saved successfully!
# CTtrain_2_0227.nii.gz saved successfully!
# CTtrain_2_0228.nii.gz saved successfully!
# CTtrain_2_0229.nii.gz saved successfully!
# CTtrain_2_0230.nii.gz saved successfully!
# CTtrain_2_0231.nii.gz saved successfully!
# CTtrain_2_0232.nii.gz saved successfully!
# CTtrain_2_0233.nii.gz saved successfully!
# CTtrain_2_0234.nii.gz saved successfully!
# CTtrain_2_0235.nii.gz saved successfully!
# CTtrain_2_0236.nii.gz saved successfully!
# CTtrain_2_0237.nii.gz saved successfully!
# CTtrain_2_0238.nii.gz saved successfully!
# CTtrain_2_0239.nii.gz saved successfully!
# CTtrain_2_0240.nii.gz saved successfully!
# CTtrain_2_0241.nii.gz saved successfully!
# CTtrain_2_0242.nii.gz saved successfully!
# CTtrain_2_0243.nii.gz saved successfully!
# CTtrain_2_0244.nii.gz saved successfully!
# CTtrain_2_0245.nii.gz saved successfully!
# CTtrain_2_0246.nii.gz saved successfully!
# CTtrain_2_0247.nii.gz saved successfully!
# CTtrain_2_0248.nii.gz saved successfully!
# CTtrain_2_0249.nii.gz saved successfully!
# CTtrain_2_0250.nii.gz saved successfully!
# CTtrain_2_0251.nii.gz saved successfully!
# CTtrain_2_0252.nii.gz saved successfully!
# CTtrain_2_0253.nii.gz saved successfully!
# CTtrain_2_0254.nii.gz saved successfully!
# CTtrain_2_0255.nii.gz saved successfully!
# CTtrain_2_0256.nii.gz saved successfully!
# CTtrain_2_0257.nii.gz saved successfully!
# CTtrain_2_0258.nii.gz saved successfully!
# CTtrain_2_0259.nii.gz saved successfully!
# CTtrain_2_0260.nii.gz saved successfully!
# CTtrain_2_0261.nii.gz saved successfully!
# CTtrain_2_0262.nii.gz saved successfully!
# CTtrain_2_0263.nii.gz saved successfully!
# CTtrain_2_0264.nii.gz saved successfully!
# CTtrain_2_0265.nii.gz saved successfully!
# CTtrain_2_0266.nii.gz saved successfully!
# CTtrain_2_0267.nii.gz saved successfully!
# CTtrain_2_0268.nii.gz saved successfully!
# CTtrain_2_0269.nii.gz saved successfully!
# CTtrain_2_0270.nii.gz saved successfully!
# CTtrain_2_0271.nii.gz saved successfully!
# CTtrain_2_0272.nii.gz saved successfully!
# CTtrain_2_0273.nii.gz saved successfully!
# CTtrain_2_0274.nii.gz saved successfully!
# CTtrain_2_0275.nii.gz saved successfully!
# CTtrain_2_0276.nii.gz saved successfully!
# CTtrain_2_0277.nii.gz saved successfully!
# CTtrain_2_0278.nii.gz saved successfully!
# CTtrain_2_0279.nii.gz saved successfully!
# CTtrain_2_0280.nii.gz saved successfully!
# CTtrain_2_0281.nii.gz saved successfully!
# CTtrain_2_0282.nii.gz saved successfully!
# CTtrain_2_0283.nii.gz saved successfully!
# CTtrain_2_0284.nii.gz saved successfully!
# CTtrain_2_0285.nii.gz saved successfully!
# CTtrain_2_0286.nii.gz saved successfully!
# CTtrain_2_0287.nii.gz saved successfully!
# CTtrain_2_0288.nii.gz saved successfully!
# CTtrain_2_0289.nii.gz saved successfully!
# CTtrain_2_0290.nii.gz saved successfully!
# CTtrain_2_0291.nii.gz saved successfully!
# CTtrain_2_0292.nii.gz saved successfully!
# CTtrain_2_0293.nii.gz saved successfully!
# CTtrain_2_0294.nii.gz saved successfully!
# CTtrain_2_0295.nii.gz saved successfully!
# CTtrain_2_0296.nii.gz saved successfully!
# CTtrain_2_0297.nii.gz saved successfully!
# CTtrain_2_0298.nii.gz saved successfully!
# CTtrain_2_0299.nii.gz saved successfully!
# CTtrain_2_0300.nii.gz saved successfully!
# CTtrain_2_0301.nii.gz saved successfully!
# CTtrain_2_0302.nii.gz saved successfully!
# CTtrain_2_0303.nii.gz saved successfully!
# CTtrain_2_0304.nii.gz saved successfully!
# CTtrain_2_0305.nii.gz saved successfully!
# CTtrain_2_0306.nii.gz saved successfully!
# CTtrain_2_0307.nii.gz saved successfully!
# CTtrain_2_0308.nii.gz saved successfully!
# CTtrain_2_0309.nii.gz saved successfully!
# CTtrain_2_0310.nii.gz saved successfully!
# CTtrain_2_0311.nii.gz saved successfully!
# CTtrain_2_0312.nii.gz saved successfully!
# CTtrain_2_0313.nii.gz saved successfully!
# CTtrain_2_0314.nii.gz saved successfully!
# CTtrain_2_0315.nii.gz saved successfully!
# CTtrain_2_0316.nii.gz saved successfully!
# CTtrain_2_0317.nii.gz saved successfully!
# CTtrain_2_0318.nii.gz saved successfully!
# CTtrain_2_0319.nii.gz saved successfully!
# CTtrain_2_0320.nii.gz saved successfully!
# CTtrain_2_0321.nii.gz saved successfully!
# CTtrain_2_0322.nii.gz saved successfully!
# CTtrain_2_0323.nii.gz saved successfully!
# CTtrain_2_0324.nii.gz saved successfully!
# CTtrain_2_0325.nii.gz saved successfully!
# CTtrain_2_0326.nii.gz saved successfully!
# CTtrain_2_0327.nii.gz saved successfully!
# CTtrain_2_0328.nii.gz saved successfully!
# CTtrain_2_0329.nii.gz saved successfully!
# CTtrain_2_0330.nii.gz saved successfully!
# CTtrain_2_0331.nii.gz saved successfully!
# CTtrain_2_0332.nii.gz saved successfully!
# CTtrain_2_0333.nii.gz saved successfully!
# CTtrain_2_0334.nii.gz saved successfully!
# CTtrain_2_0335.nii.gz saved successfully!
# CTtrain_2_0336.nii.gz saved successfully!
# CTtrain_2_0337.nii.gz saved successfully!
# CTtrain_2_0338.nii.gz saved successfully!
# CTtrain_2_0339.nii.gz saved successfully!
# CTtrain_2_0340.nii.gz saved successfully!
# CTtrain_2_0341.nii.gz saved successfully!
# CTtrain_2_0342.nii.gz saved successfully!
# CTtrain_2_0343.nii.gz saved successfully!
# CTtrain_2_0344.nii.gz saved successfully!
# CTtrain_2_0345.nii.gz saved successfully!
# CTtrain_2_0346.nii.gz saved successfully!
# CTtrain_2_0347.nii.gz saved successfully!
# CTtrain_2_0348.nii.gz saved successfully!
# CTtrain_2_0349.nii.gz saved successfully!
# CTtrain_2_0350.nii.gz saved successfully!
# CTtrain_2_0351.nii.gz saved successfully!
# CTtrain_2_0352.nii.gz saved successfully!
# CTtrain_2_0353.nii.gz saved successfully!
# CTtrain_2_0354.nii.gz saved successfully!
# CTtrain_2_0355.nii.gz saved successfully!
# CTtrain_2_0356.nii.gz saved successfully!
# CTtrain_2_0357.nii.gz saved successfully!
# CTtrain_2_0358.nii.gz saved successfully!
# CTtrain_2_0359.nii.gz saved successfully!
# CTtrain_2_0360.nii.gz saved successfully!
# CTtrain_2_0361.nii.gz saved successfully!
# CTtrain_2_0362.nii.gz saved successfully!
# CTtrain_2_0363.nii.gz saved successfully!
# CTtrain_2_0364.nii.gz saved successfully!
# CTtrain_2_0365.nii.gz saved successfully!
# CTtrain_2_0366.nii.gz saved successfully!
# CTtrain_2_0367.nii.gz saved successfully!
# CTtrain_2_0368.nii.gz saved successfully!
# CTtrain_2_0369.nii.gz saved successfully!
# CTtrain_2_0370.nii.gz saved successfully!
# CTtrain_2_0371.nii.gz saved successfully!
# CTtrain_2_0372.nii.gz saved successfully!
# CTtrain_2_0373.nii.gz saved successfully!
# CTtrain_2_0374.nii.gz saved successfully!
# ...
# CTlabel_20_0013.nii.gz saved successfully!
# CTlabel_20_0014.nii.gz saved successfully!
# CTlabel_20_0015.nii.gz saved successfully!
# CTlabel_20_0016.nii.gz saved successfully!
# CTlabel_20_0017.nii.gz saved successfully!
# CTlabel_20_0018.nii.gz saved successfully!
# CTlabel_20_0019.nii.gz saved successfully!
# CTlabel_20_0020.nii.gz saved successfully!
# CTlabel_20_0021.nii.gz saved successfully!
# CTlabel_20_0022.nii.gz saved successfully!
# CTlabel_20_0023.nii.gz saved successfully!
# CTlabel_20_0024.nii.gz saved successfully!
# CTlabel_20_0025.nii.gz saved successfully!
# CTlabel_20_0026.nii.gz saved successfully!
# CTlabel_20_0027.nii.gz saved successfully!
# CTlabel_20_0028.nii.gz saved successfully!
# CTlabel_20_0029.nii.gz saved successfully!
# CTlabel_20_0030.nii.gz saved successfully!
# CTlabel_20_0031.nii.gz saved successfully!
# CTlabel_20_0032.nii.gz saved successfully!
# CTlabel_20_0033.nii.gz saved successfully!
# CTlabel_20_0034.nii.gz saved successfully!
# CTlabel_20_0035.nii.gz saved successfully!
# CTlabel_20_0036.nii.gz saved successfully!
# CTlabel_20_0037.nii.gz saved successfully!
# CTlabel_20_0038.nii.gz saved successfully!
# CTlabel_20_0039.nii.gz saved successfully!
# CTlabel_20_0040.nii.gz saved successfully!
# CTlabel_20_0041.nii.gz saved successfully!
# CTlabel_20_0042.nii.gz saved successfully!
# CTlabel_20_0043.nii.gz saved successfully!
# CTlabel_20_0044.nii.gz saved successfully!
# CTlabel_20_0045.nii.gz saved successfully!
# CTlabel_20_0046.nii.gz saved successfully!
# CTlabel_20_0047.nii.gz saved successfully!
# CTlabel_20_0048.nii.gz saved successfully!
# CTlabel_20_0049.nii.gz saved successfully!
# CTlabel_20_0050.nii.gz saved successfully!
# CTlabel_20_0051.nii.gz saved successfully!
# CTlabel_20_0052.nii.gz saved successfully!
# CTlabel_20_0053.nii.gz saved successfully!
# CTlabel_20_0054.nii.gz saved successfully!
# CTlabel_20_0055.nii.gz saved successfully!
# CTlabel_20_0056.nii.gz saved successfully!
# CTlabel_20_0057.nii.gz saved successfully!
# CTlabel_20_0058.nii.gz saved successfully!
# CTlabel_20_0059.nii.gz saved successfully!
# CTlabel_20_0060.nii.gz saved successfully!
# CTlabel_20_0061.nii.gz saved successfully!
# CTlabel_20_0062.nii.gz saved successfully!
# CTlabel_20_0063.nii.gz saved successfully!
# CTlabel_20_0064.nii.gz saved successfully!
# CTlabel_20_0065.nii.gz saved successfully!
# CTlabel_20_0066.nii.gz saved successfully!
# CTlabel_20_0067.nii.gz saved successfully!
# CTlabel_20_0068.nii.gz saved successfully!
# CTlabel_20_0069.nii.gz saved successfully!
# CTlabel_20_0070.nii.gz saved successfully!
# CTlabel_20_0071.nii.gz saved successfully!
# CTlabel_20_0072.nii.gz saved successfully!
# CTlabel_20_0073.nii.gz saved successfully!
# CTlabel_20_0074.nii.gz saved successfully!
# CTlabel_20_0075.nii.gz saved successfully!
# CTlabel_20_0076.nii.gz saved successfully!
# CTlabel_20_0077.nii.gz saved successfully!
# CTlabel_20_0078.nii.gz saved successfully!
# CTlabel_20_0079.nii.gz saved successfully!
# CTlabel_20_0080.nii.gz saved successfully!
# CTlabel_20_0081.nii.gz saved successfully!
# CTlabel_20_0082.nii.gz saved successfully!
# CTlabel_20_0083.nii.gz saved successfully!
# CTlabel_20_0084.nii.gz saved successfully!
# CTlabel_20_0085.nii.gz saved successfully!
# CTlabel_20_0086.nii.gz saved successfully!
# CTlabel_20_0087.nii.gz saved successfully!
# CTlabel_20_0088.nii.gz saved successfully!
# CTlabel_20_0089.nii.gz saved successfully!
# CTlabel_20_0090.nii.gz saved successfully!
# CTlabel_20_0091.nii.gz saved successfully!
# CTlabel_20_0092.nii.gz saved successfully!
# CTlabel_20_0093.nii.gz saved successfully!
# CTlabel_20_0094.nii.gz saved successfully!
# CTlabel_20_0095.nii.gz saved successfully!
# CTlabel_20_0096.nii.gz saved successfully!
# CTlabel_20_0097.nii.gz saved successfully!
# CTlabel_20_0098.nii.gz saved successfully!
# CTlabel_20_0099.nii.gz saved successfully!
# CTlabel_20_0100.nii.gz saved successfully!
# CTlabel_20_0101.nii.gz saved successfully!
# CTlabel_20_0102.nii.gz saved successfully!
# CTlabel_20_0103.nii.gz saved successfully!
# CTlabel_20_0104.nii.gz saved successfully!
# CTlabel_20_0105.nii.gz saved successfully!
# CTlabel_20_0106.nii.gz saved successfully!
# CTlabel_20_0107.nii.gz saved successfully!
# CTlabel_20_0108.nii.gz saved successfully!
# CTlabel_20_0109.nii.gz saved successfully!
# CTlabel_20_0110.nii.gz saved successfully!
# CTlabel_20_0111.nii.gz saved successfully!
# CTlabel_20_0112.nii.gz saved successfully!
# CTlabel_20_0113.nii.gz saved successfully!
# CTlabel_20_0114.nii.gz saved successfully!
# CTlabel_20_0115.nii.gz saved successfully!
# CTlabel_20_0116.nii.gz saved successfully!
# CTlabel_20_0117.nii.gz saved successfully!
# CTlabel_20_0118.nii.gz saved successfully!
# CTlabel_20_0119.nii.gz saved successfully!
# CTlabel_20_0120.nii.gz saved successfully!
# CTlabel_20_0121.nii.gz saved successfully!
# CTlabel_20_0122.nii.gz saved successfully!
# CTlabel_20_0123.nii.gz saved successfully!
# CTlabel_20_0124.nii.gz saved successfully!
# CTlabel_20_0125.nii.gz saved successfully!
# CTlabel_20_0126.nii.gz saved successfully!
# CTlabel_20_0127.nii.gz saved successfully!
# CTlabel_20_0128.nii.gz saved successfully!
# CTlabel_20_0129.nii.gz saved successfully!
# CTlabel_20_0130.nii.gz saved successfully!
# CTlabel_20_0131.nii.gz saved successfully!
# CTlabel_20_0132.nii.gz saved successfully!
# CTlabel_20_0133.nii.gz saved successfully!
# CTlabel_20_0134.nii.gz saved successfully!
# CTlabel_20_0135.nii.gz saved successfully!
# CTlabel_20_0136.nii.gz saved successfully!
# CTlabel_20_0137.nii.gz saved successfully!
# CTlabel_20_0138.nii.gz saved successfully!
# CTlabel_20_0139.nii.gz saved successfully!
# CTlabel_20_0140.nii.gz saved successfully!
# CTlabel_20_0141.nii.gz saved successfully!
# CTlabel_20_0142.nii.gz saved successfully!
# CTlabel_20_0143.nii.gz saved successfully!
# CTlabel_20_0144.nii.gz saved successfully!
# CTlabel_20_0145.nii.gz saved successfully!
# CTlabel_20_0146.nii.gz saved successfully!
# CTlabel_20_0147.nii.gz saved successfully!
# CTlabel_20_0148.nii.gz saved successfully!
# CTlabel_20_0149.nii.gz saved successfully!
# CTlabel_20_0150.nii.gz saved successfully!
# CTlabel_20_0151.nii.gz saved successfully!
# CTlabel_20_0152.nii.gz saved successfully!
# CTlabel_20_0153.nii.gz saved successfully!
# CTlabel_20_0154.nii.gz saved successfully!
# CTlabel_20_0155.nii.gz saved successfully!
# CTlabel_20_0156.nii.gz saved successfully!
# CTlabel_20_0157.nii.gz saved successfully!
# CTlabel_20_0158.nii.gz saved successfully!
# CTlabel_20_0159.nii.gz saved successfully!
# CTlabel_20_0160.nii.gz saved successfully!
# CTlabel_20_0161.nii.gz saved successfully!
# CTlabel_20_0162.nii.gz saved successfully!
# CTlabel_20_0163.nii.gz saved successfully!
# CTlabel_20_0164.nii.gz saved successfully!
# CTlabel_20_0165.nii.gz saved successfully!
# CTlabel_20_0166.nii.gz saved successfully!
# CTlabel_20_0167.nii.gz saved successfully!
# CTlabel_20_0168.nii.gz saved successfully!
# CTlabel_20_0169.nii.gz saved successfully!
# CTlabel_20_0170.nii.gz saved successfully!
# CTlabel_20_0171.nii.gz saved successfully!
# CTlabel_20_0172.nii.gz saved successfully!
# CTlabel_20_0173.nii.gz saved successfully!
# CTlabel_20_0174.nii.gz saved successfully!
# CTlabel_20_0175.nii.gz saved successfully!
# CTlabel_20_0176.nii.gz saved successfully!
# CTlabel_20_0177.nii.gz saved successfully!
# CTlabel_20_0178.nii.gz saved successfully!
# CTlabel_20_0179.nii.gz saved successfully!
# CTlabel_20_0180.nii.gz saved successfully!
# CTlabel_20_0181.nii.gz saved successfully!
# CTlabel_20_0182.nii.gz saved successfully!
# CTlabel_20_0183.nii.gz saved successfully!
# CTlabel_20_0184.nii.gz saved successfully!
# CTlabel_20_0185.nii.gz saved successfully!
# CTlabel_20_0186.nii.gz saved successfully!
# CTlabel_20_0187.nii.gz saved successfully!
# CTlabel_20_0188.nii.gz saved successfully!
# CTlabel_20_0189.nii.gz saved successfully!
# CTlabel_20_0190.nii.gz saved successfully!
# CTlabel_20_0191.nii.gz saved successfully!
# CTlabel_20_0192.nii.gz saved successfully!
# CTlabel_20_0193.nii.gz saved successfully!
# CTlabel_20_0194.nii.gz saved successfully!
# CTlabel_20_0195.nii.gz saved successfully!
# CTlabel_20_0196.nii.gz saved successfully!
# CTlabel_20_0197.nii.gz saved successfully!
# CTlabel_20_0198.nii.gz saved successfully!
# CTlabel_20_0199.nii.gz saved successfully!
# CTlabel_20_0200.nii.gz saved successfully!
# CTlabel_20_0201.nii.gz saved successfully!
# CTlabel_20_0202.nii.gz saved successfully!
# CTlabel_20_0203.nii.gz saved successfully!
# CTlabel_20_0204.nii.gz saved successfully!
# CTlabel_20_0205.nii.gz saved successfully!
# CTlabel_20_0206.nii.gz saved successfully!
# CTlabel_20_0207.nii.gz saved successfully!
# CTlabel_20_0208.nii.gz saved successfully!
# CTlabel_20_0209.nii.gz saved successfully!
# CTlabel_20_0210.nii.gz saved successfully!
# CTlabel_20_0211.nii.gz saved successfully!
# CTlabel_20_0212.nii.gz saved successfully!
# CTlabel_20_0213.nii.gz saved successfully!
# CTlabel_20_0214.nii.gz saved successfully!
# CTlabel_20_0215.nii.gz saved successfully!
# CTlabel_20_0216.nii.gz saved successfully!
# CTlabel_20_0217.nii.gz saved successfully!
# CTlabel_20_0218.nii.gz saved successfully!
# CTlabel_20_0219.nii.gz saved successfully!
# CTlabel_20_0220.nii.gz saved successfully!
# CTlabel_20_0221.nii.gz saved successfully!
# CTlabel_20_0222.nii.gz saved successfully!
# CTlabel_20_0223.nii.gz saved successfully!
# CTlabel_20_0224.nii.gz saved successfully!
# CTlabel_20_0225.nii.gz saved successfully!
# CTlabel_20_0226.nii.gz saved successfully!
# CTlabel_20_0227.nii.gz saved successfully!
# CTlabel_20_0228.nii.gz saved successfully!
# CTlabel_20_0229.nii.gz saved successfully!
# CTlabel_20_0230.nii.gz saved successfully!
# CTlabel_20_0231.nii.gz saved successfully!
# CTlabel_20_0232.nii.gz saved successfully!
# CTlabel_20_0233.nii.gz saved successfully!
# CTlabel_20_0234.nii.gz saved successfully!
# CTlabel_20_0235.nii.gz saved successfully!
# CTlabel_20_0236.nii.gz saved successfully!
# CTlabel_20_0237.nii.gz saved successfully!
# CTlabel_20_0238.nii.gz saved successfully!
# CTlabel_20_0239.nii.gz saved successfully!
# CTlabel_20_0240.nii.gz saved successfully!
# CTlabel_20_0241.nii.gz saved successfully!
# CTlabel_20_0242.nii.gz saved successfully!
# CTlabel_20_0243.nii.gz saved successfully!
# CTlabel_20_0244.nii.gz saved successfully!
# CTlabel_20_0245.nii.gz saved successfully!
# CTlabel_20_0246.nii.gz saved successfully!
# CTlabel_20_0247.nii.gz saved successfully!
# CTlabel_20_0248.nii.gz saved successfully!
# CTlabel_20_0249.nii.gz saved successfully!
# CTlabel_20_0250.nii.gz saved successfully!
# CTlabel_20_0251.nii.gz saved successfully!
# CTlabel_20_0252.nii.gz saved successfully!
# CTlabel_20_0253.nii.gz saved successfully!
# CTlabel_20_0254.nii.gz saved successfully!
# CTlabel_20_0255.nii.gz saved successfully!
# CTlabel_20_0256.nii.gz saved successfully!
# CTlabel_20_0257.nii.gz saved successfully!
# CTlabel_20_0258.nii.gz saved successfully!
# CTlabel_20_0259.nii.gz saved successfully!
# CTlabel_20_0260.nii.gz saved successfully!
# CTlabel_20_0261.nii.gz saved successfully!
# CTlabel_20_0262.nii.gz saved successfully!
# CTlabel_20_0263.nii.gz saved successfully!
# CTlabel_20_0264.nii.gz saved successfully!
# CTlabel_20_0265.nii.gz saved successfully!
# CTlabel_20_0266.nii.gz saved successfully!
# CTlabel_20_0267.nii.gz saved successfully!
# CTlabel_20_0268.nii.gz saved successfully!
# CTlabel_20_0269.nii.gz saved successfully!
# CTlabel_20_0270.nii.gz saved successfully!
# CTlabel_20_0271.nii.gz saved successfully!
# CTlabel_20_0272.nii.gz saved successfully!
# CTlabel_20_0273.nii.gz saved successfully!
# CTlabel_20_0274.nii.gz saved successfully!
# CTlabel_20_0275.nii.gz saved successfully!
# CTlabel_20_0276.nii.gz saved successfully!
# CTlabel_20_0277.nii.gz saved successfully!
# CTlabel_20_0278.nii.gz saved successfully!
# CTlabel_20_0279.nii.gz saved successfully!
# CTlabel_20_0280.nii.gz saved successfully!
# CTlabel_20_0281.nii.gz saved successfully!
# CTlabel_20_0282.nii.gz saved successfully!
# CTlabel_20_0283.nii.gz saved successfully!
# CTlabel_20_0284.nii.gz saved successfully!
# CTlabel_20_0285.nii.gz saved successfully!
# CTlabel_20_0286.nii.gz saved successfully!
# CTlabel_20_0287.nii.gz saved successfully!
# CTlabel_20_0288.nii.gz saved successfully!
# CTlabel_20_0289.nii.gz saved successfully!
# CTlabel_20_0290.nii.gz saved successfully!
# CTlabel_20_0291.nii.gz saved successfully!
# CTlabel_20_0292.nii.gz saved successfully!
# CTlabel_20_0293.nii.gz saved successfully!
# CTlabel_20_0294.nii.gz saved successfully!
# CTlabel_20_0295.nii.gz saved successfully!
# CTlabel_20_0296.nii.gz saved successfully!
# CTlabel_20_0297.nii.gz saved successfully!
# CTlabel_20_0298.nii.gz saved successfully!
# CTlabel_20_0299.nii.gz saved successfully!
# CTlabel_20_0300.nii.gz saved successfully!
# CTlabel_20_0301.nii.gz saved successfully!
# CTlabel_20_0302.nii.gz saved successfully!
# CTlabel_20_0303.nii.gz saved successfully!
# CTlabel_20_0304.nii.gz saved successfully!
# CTlabel_20_0305.nii.gz saved successfully!
# CTlabel_20_0306.nii.gz saved successfully!
# CTlabel_20_0307.nii.gz saved successfully!
# CTlabel_20_0308.nii.gz saved successfully!
# CTlabel_20_0309.nii.gz saved successfully!
# CTlabel_20_0310.nii.gz saved successfully!
# CTlabel_20_0311.nii.gz saved successfully!
# CTlabel_20_0312.nii.gz saved successfully!
# CTlabel_20_0313.nii.gz saved successfully!
# CTlabel_20_0314.nii.gz saved successfully!
# CTlabel_20_0315.nii.gz saved successfully!
# CTlabel_20_0316.nii.gz saved successfully!
# CTlabel_20_0317.nii.gz saved successfully!
# CTlabel_20_0318.nii.gz saved successfully!
# CTlabel_20_0319.nii.gz saved successfully!
# CTlabel_20_0320.nii.gz saved successfully!
# CTlabel_20_0321.nii.gz saved successfully!
# CTlabel_20_0322.nii.gz saved successfully!
# CTlabel_20_0323.nii.gz saved successfully!
# CTlabel_20_0324.nii.gz saved successfully!
# CTlabel_20_0325.nii.gz saved successfully!
# CTlabel_20_0326.nii.gz saved successfully!
# CTlabel_20_0327.nii.gz saved successfully!
# CTlabel_20_0328.nii.gz saved successfully!
# CTlabel_20_0329.nii.gz saved successfully!
# CTlabel_20_0330.nii.gz saved successfully!
# CTlabel_20_0331.nii.gz saved successfully!
# CTlabel_20_0332.nii.gz saved successfully!
# CTlabel_20_0333.nii.gz saved successfully!
# CTlabel_20_0334.nii.gz saved successfully!
# CTlabel_20_0335.nii.gz saved successfully!
# CTlabel_20_0336.nii.gz saved successfully!
# CTlabel_20_0337.nii.gz saved successfully!
# CTlabel_20_0338.nii.gz saved successfully!
# CTlabel_20_0339.nii.gz saved successfully!
# CTlabel_20_0340.nii.gz saved successfully!
# CTlabel_20_0341.nii.gz saved successfully!
# CTlabel_20_0342.nii.gz saved successfully!
# CTlabel_20_0343.nii.gz saved successfully!
# CTlabel_20_0344.nii.gz saved successfully!
# CTlabel_20_0345.nii.gz saved successfully!
# CTlabel_20_0346.nii.gz saved successfully!
# CTlabel_20_0347.nii.gz saved successfully!
# CTlabel_20_0348.nii.gz saved successfully!
# CTlabel_20_0349.nii.gz saved successfully!
# CTlabel_20_0350.nii.gz saved successfully!
# CTlabel_20_0351.nii.gz saved successfully!
# CTlabel_20_0352.nii.gz saved successfully!
# CTlabel_20_0353.nii.gz saved successfully!
# CTlabel_20_0354.nii.gz saved successfully!
# CTlabel_20_0355.nii.gz saved successfully!
# CTlabel_20_0356.nii.gz saved successfully!
# CTlabel_20_0357.nii.gz saved successfully!
# CTlabel_20_0358.nii.gz saved successfully!
# CTlabel_20_0359.nii.gz saved successfully!
# CTlabel_20_0360.nii.gz saved successfully!
# CTlabel_20_0361.nii.gz saved successfully!
# CTlabel_20_0362.nii.gz saved successfully!
# CTlabel_20_0363.nii.gz saved successfully!
# CTlabel_20_0364.nii.gz saved successfully!
# CTlabel_20_0365.nii.gz saved successfully!
# CTlabel_20_0366.nii.gz saved successfully!
# CTlabel_20_0367.nii.gz saved successfully!
# CTlabel_20_0368.nii.gz saved successfully!
# CTlabel_20_0369.nii.gz saved successfully!
# CTlabel_20_0370.nii.gz saved successfully!
# CTlabel_20_0371.nii.gz saved successfully!
# CTlabel_20_0372.nii.gz saved successfully!
# CTlabel_20_0373.nii.gz saved successfully!
# CTlabel_20_0374.nii.gz saved successfully!
# CTlabel_20_0375.nii.gz saved successfully!
# CTlabel_20_0376.nii.gz saved successfully!
# CTlabel_20_0377.nii.gz saved successfully!
# CTlabel_20_0378.nii.gz saved successfully!
# CTlabel_20_0379.nii.gz saved successfully!
# CTlabel_20_0380.nii.gz saved successfully!
# CTlabel_20_0381.nii.gz saved successfully!
# CTlabel_20_0382.nii.gz saved successfully!
# CTlabel_20_0383.nii.gz saved successfully!
# CTlabel_20_0384.nii.gz saved successfully!
